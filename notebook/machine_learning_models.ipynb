# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, make_scorer
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import joblib

# %%
data = pd.read_parquet('../data/ML_data/ML_train_data.parquet')
data.drop(['Station_Name', 'Business_Date', 'PublicHoliday', 'Date'], axis=1, inplace=True)
y = data['log_Total_Demand']
X = data.drop(['log_Total_Demand'], axis=1)

# %%
data
# Out:
#        Weekday  log_Total_Demand  mean_rainfall_value  has_school  \
# 0            0         -1.590078            -1.556931           0
# 1            0         -2.677412            -1.556931           0
# 2            1         -2.290096            -1.556931           0
# 3            1         -1.676214            -1.556931           0
# 4            1         -1.449649            -1.556931           0
# ...        ...               ...                  ...         ...
# 79949        0          0.697757            -1.175627           1
# 79950        0          0.595880            -1.175627           1
# 79951        1          0.652032            -1.175627           1
# 79952        1          0.733820            -1.175627           1
# 79953        1          0.785033            -1.175627           1
#
#        has_sport_facility  has_shopping_centre  has_hospital  \
# 0                       0                    0             0
# 1                       0                    0             0
# 2                       0                    0             0
# 3                       0                    0             0
# 4                       0                    0             0
# ...                   ...                  ...           ...
# 79949                   1                    0             0
# 79950                   1                    0             0
# 79951                   1                    0             0
# 79952                   1                    0             0
# 79953                   1                    0             0
#
#        total_population   med_rent_weekly_c2021   med_mortg_rep_mon_c2021  \
# 0             -0.829089               -0.355036                 -0.459351
# 1             -0.829089               -0.355036                 -0.459351
# 2             -0.829089               -0.355036                 -0.459351
# 3             -0.829089               -0.355036                 -0.459351
# 4             -0.829089               -0.355036                 -0.459351
# ...                 ...                     ...                       ...
# 79949          0.229075                0.510369                  0.581919
# 79950          0.229075                0.510369                  0.581919
# 79951          0.229075                0.510369                  0.581919
# 79952          0.229075                0.510369                  0.581919
# 79953          0.229075                0.510369                  0.581919
#
#        ...   Westall  Westgarth   Westona  Williams Landing  Williamstown  \
# 0      ... -1.251021  -0.997419  1.030019          2.494975      0.505772
# 1      ... -1.252371  -0.986387  1.528683          2.569257      0.557268
# 2      ... -1.248455  -1.722069  1.613901          2.630175      0.547518
# 3      ... -1.239132  -1.722069  1.572998          2.904756      0.483018
# 4      ... -1.240119  -1.722069  1.572998          2.829185      0.172741
# ...    ...       ...        ...       ...               ...           ...
# 79949  ... -0.471748   0.740544  1.716632          1.735370      2.091581
# 79950  ... -0.494365   0.654487  1.654215          1.668574      1.539415
# 79951  ... -0.485176   0.624070  1.784640          1.949590      1.511881
# 79952  ... -0.481339   0.700083  1.891953          2.032609      1.630725
# 79953  ... -0.476490   0.740544  1.944546          2.031695      1.584156
#
#        Williamstown Beach  Willison   Windsor  Yarraman  Yarraville
# 0                0.767413 -1.412212 -0.841184 -0.978305    0.307137
# 1                0.844431 -1.412212 -0.811846 -0.986107    0.304484
# 2                0.642515 -1.412212 -0.876631 -0.990132    0.327493
# 3                0.679989 -1.141728 -0.781095 -0.986107    0.398527
# 4                0.515339 -1.141728 -0.777384 -0.981542    0.392771
# ...                   ...       ...       ...       ...         ...
# 79949            1.552048 -0.651573  0.798081 -0.677804   -1.621478
# 79950            1.674669 -0.119909  0.628862 -0.693987   -1.621478
# 79951            1.633596  0.264328  0.704559 -0.717370   -1.621478
# 79952            1.606028  0.354159  0.765183 -0.739428   -1.621478
# 79953            1.829158  0.321097  0.777908 -0.750858   -1.621478
#
# [79954 rows x 235 columns]

# %%
validation = pd.read_parquet('../data/ML_data/ML_val_data.parquet')
validation.drop(['Station_Name', 'Business_Date', 'PublicHoliday', 'Date'], axis=1, inplace=True)
y_val = validation['log_Total_Demand']
X_val = validation.drop(['log_Total_Demand'], axis=1)

# %% [markdown]
# ### Linear Regression

# %%
def stepwise_selection(X, y,
                       initial_list=[],
                       threshold_in=0.05,
                       threshold_out = 0.05,
                       verbose=True):
    """
    Perform a forward-backward feature selection
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns:
        - list of selected features
        - fitted model with selected features
    """
    included = list(initial_list)
    while True:
        changed=False

        # Forward step
        excluded = list(set(X.columns) - set(included))
        new_pval = pd.Series(index=excluded, dtype='float64')
        for new_column in excluded:
            model = sm.OLS(y, (pd.DataFrame(X[included + [new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print(f'Added {best_feature} with p-value {best_pval:.6}')

        # Backward step
        model = sm.OLS(y, (pd.DataFrame(X[included]))).fit()
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max()
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
            if verbose:
                print(f'Dropped {worst_feature} with p-value {worst_pval:.6}')
        if not changed:
            break

    # Fit the model with the final selected features
    final_model = sm.OLS(y, (pd.DataFrame(X[included]))).fit()

    return included, final_model

X_const = sm.add_constant(X)
X_val_const = sm.add_constant(X_val)
selected_features, final_model = stepwise_selection(X_const, y)
# Out:
# Added Jacana with p-value 0.0
# Added West Footscray with p-value 0.0
# Added Tooronga with p-value 0.0
# Added Officer with p-value 0.0
# Added Wattle Glen with p-value 0.0
# Added Williams Landing with p-value 0.0
# Added Mordialloc with p-value 0.0
# Added Aircraft with p-value 0.0
# Added Mooroolbark with p-value 0.0
# Added Crib Point with p-value 0.0
# Added Frankston with p-value 0.0
# Dropped West Footscray with p-value 0.381213
# Added Southern Cross with p-value 0.0
# Added Aspendale with p-value 0.0
# Added has_hospital with p-value 0.0
# Dropped Mooroolbark with p-value 0.058723
# Added Upfield with p-value 0.0
# Added  med_mortg_rep_mon_c2021 with p-value 0.0
# Added  med_person_inc_we_c2021 with p-value 0.0
# Added  med_famly_inc_we_c2021 with p-value 0.0
# Added total_population with p-value 0.0
# Added Flinders Street with p-value 0.0
# Dropped  med_mortg_rep_mon_c2021 with p-value 0.462761
# Added Hastings with p-value 0.0
# Added Richmond with p-value 0.0
# Added Collingwood with p-value 0.0
# Added mean_rainfall_value with p-value 0.0
# Added Tecoma with p-value 0.0
# Added has_shopping_centre with p-value 0.0
# Dropped Williams Landing with p-value 0.853478
# Added const with p-value 0.0
# Dropped Crib Point with p-value 0.471979
# Added has_school with p-value 7.86225e-239
# Dropped Southern Cross with p-value 0.253078
# Added Alamein with p-value 1.48441e-246
# Added Bonbeach with p-value 2.69127e-207
# Added Seaholme with p-value 3.11352e-212
# Added Newport with p-value 3.49112e-283
# Added Seaford with p-value 2.15669e-139
# Added Fairfield with p-value 6.40137e-133
# Added Footscray with p-value 1.41066e-124
# Added Middle Footscray with p-value 3.34674e-138
# Added Sunshine with p-value 4.40871e-251
# Added Leawarra with p-value 1.88227e-120
# Added Prahran with p-value 1.17854e-107
# Added Eaglemont with p-value 2.02847e-106
# Added North Melbourne with p-value 3.56292e-98
# Added Pakenham with p-value 2.64846e-94
# Added Diggers Rest with p-value 8.31988e-95
# Added Edithvale with p-value 2.92925e-89
# Added Flagstaff with p-value 1.18399e-76
# Added Caulfield with p-value 1.47218e-87
# Added Hawksburn with p-value 1.8905e-219
# Added Kananook with p-value 4.18708e-87
# Added Fawkner with p-value 5.22583e-77
# Added Craigieburn with p-value 6.52268e-83
# Added Cheltenham with p-value 4.37326e-84
# Added Yarraman with p-value 9.73315e-72
# Added Springvale with p-value 2.37122e-156
# Added Dandenong with p-value 2.65724e-73
# Added Laverton with p-value 8.91079e-74
# Added Upper Ferntree Gully with p-value 2.03217e-80
# Added Williamstown with p-value 1.88418e-79
# Added Yarraville with p-value 2.04997e-88
# Added Glenferrie with p-value 4.14224e-75
# Added Kooyong with p-value 2.73009e-97
# Added Southern Cross with p-value 9.12015e-67
# Added Middle Gorge with p-value 1.22839e-65
# Added Clifton Hill with p-value 2.69094e-67
# Added Essendon with p-value 5.14409e-60
# Added Box Hill with p-value 1.18669e-54
# Added Laburnum with p-value 2.10127e-85
# Added Windsor with p-value 5.41551e-55
# Added North Brighton with p-value 2.92112e-56
# Added Lynbrook with p-value 1.36646e-50
# Added Huntingdale with p-value 4.79228e-56
# Added Cranbourne with p-value 6.74013e-53
# Added Clayton with p-value 1.82361e-53
# Added Coolaroo with p-value 6.42472e-50
# Added Pascoe Vale with p-value 1.46975e-54
# Dropped Upfield with p-value 0.356977
# Added Altona with p-value 1.55802e-52
# Added Bayswater with p-value 1.96124e-49
# Added Belgrave with p-value 3.40589e-71
# Added Cardinia Road with p-value 6.22892e-58
# Added Ringwood East with p-value 3.32896e-54
# Added Lilydale with p-value 6.72528e-52
# Added  med_rent_weekly_c2021 with p-value 1.01795e-48
# Added  med_mortg_rep_mon_c2021 with p-value 1.73212e-138
# Added Watergardens with p-value 8.32527e-56
# Added Noble Park with p-value 1.35163e-52
# Added Blackburn with p-value 4.3493e-52
# Added Bentleigh with p-value 4.31268e-54
# Added Holmesglen with p-value 1.04283e-49
# Added Burnley with p-value 1.10206e-55
# Added Parkdale with p-value 1.97805e-49
# Added Elsternwick with p-value 1.26519e-51
# Added Melbourne Central with p-value 1.42523e-47
# Added Coburg with p-value 1.81292e-46
# Added Roxburgh Park with p-value 2.28547e-46
# Added Gardiner with p-value 5.05581e-45
# Added Mooroolbark with p-value 1.88311e-41
# Added Boronia with p-value 3.013e-42
# Added Westona with p-value 2.26656e-43
# Added Kensington with p-value 8.75433e-34
# Added Royal Park with p-value 4.33434e-73
# Added Upfield with p-value 1.84184e-48
# Added East Malvern with p-value 4.72044e-39
# Added Watsonia with p-value 1.31827e-34
# Added Williamstown Beach with p-value 6.85006e-37
# Added Spotswood with p-value 4.06261e-39
# Added Merinda Park with p-value 1.45975e-32
# Added Hartwell with p-value 2.93898e-32
# Added Macaulay with p-value 3.87877e-32
# Added Heatherdale with p-value 4.15376e-30
# Added Mckinnon with p-value 6.83783e-31
# Added Lalor with p-value 1.3258e-30
# Added Glen Iris with p-value 8.82099e-30
# Added Jordanville with p-value 3.18803e-33
# Added Keilor Plains with p-value 3.39063e-30
# Added Anstey with p-value 3.04881e-28
# Added North Richmond with p-value 4.99021e-26
# Added North Williamstown with p-value 2.77981e-31
# Added Middle Brighton with p-value 7.03777e-28
# Added Highett with p-value 2.81306e-26
# Added Hoppers Crossing with p-value 2.74357e-27
# Added Balaclava with p-value 4.55667e-25
# Added Rosanna with p-value 9.85668e-24
# Added South Kensington with p-value 1.15644e-25
# Added Tottenham with p-value 1.9366e-27
# Added Parliament with p-value 2.49003e-26
# Added Moonee Ponds with p-value 1.355e-24
# Added Oakleigh with p-value 3.54219e-25
# Added West Richmond with p-value 7.63479e-25
# Added Ivanhoe with p-value 2.32116e-25
# Added Stony Point with p-value 3.49022e-24
# Added Reservoir with p-value 5.99936e-21
# Added Macleod with p-value 4.28585e-21
# Added Ascot Vale with p-value 2.8043e-20
# Added Camberwell with p-value 1.78867e-20
# Added Baxter with p-value 1.26913e-19
# Added Carnegie with p-value 2.07678e-18
# Added Broadmeadows with p-value 2.26232e-17
# Added Moorabbin with p-value 8.92751e-18
# Added Sandringham with p-value 7.69741e-20
# Added Southland with p-value 1.31945e-17
# Added Dennis with p-value 1.74841e-16
# Added Darebin with p-value 1.87094e-20
# Added Nunawading with p-value 3.10243e-16
# Added Glenroy with p-value 4.7631e-17
# Added Preston with p-value 2.94815e-18
# Added Glenbervie with p-value 1.28692e-18
# Added Moreland with p-value 8.05019e-18
# Added Ginifer with p-value 1.57573e-18
# Added Ruthven with p-value 4.10055e-19
# Added Croxton with p-value 5.80882e-21
# Added Mont Albert with p-value 1.25159e-17
# Added Chatham with p-value 1.68323e-56
# Added Ripponlea with p-value 9.40637e-19
# Added Rushall with p-value 1.47939e-19
# Added Sunbury with p-value 1.82981e-18
# Added Hawthorn with p-value 7.07718e-17
# Added Armadale with p-value 4.81384e-17
# Added Alphington with p-value 1.09462e-16
# Added Hampton with p-value 1.51928e-16
# Added Brighton Beach with p-value 1.23028e-23
# Added Eltham with p-value 6.43195e-17
# Added Greensborough with p-value 1.23426e-26
# Added Glen Waverley with p-value 1.09622e-15
# Added has_sport_facility with p-value 2.27705e-24
# Added Hurstbridge with p-value 1.80304e-20
# Added Patterson with p-value 4.48254e-18
# Added Westall with p-value 2.87438e-15
# Added Westgarth with p-value 1.04229e-15
# Added Montmorency with p-value 6.80447e-15
# Added Williams Landing with p-value 1.07773e-14
# Added Mount Waverley with p-value 6.46063e-14
# Added Carrum with p-value 1.68034e-13
# Added Tyabb with p-value 7.11512e-12
# Added Epping with p-value 3.13574e-11
# Added Ringwood with p-value 1.43577e-10
# Added Jewell with p-value 3.61629e-10
# Added Mitcham with p-value 5.32141e-10
# Added Weekday with p-value 6.91004e-10
# Added Diamond Creek with p-value 8.43973e-10
# Added St Albans with p-value 8.82643e-10
# Added Chelsea with p-value 2.74097e-09
# Added Toorak with p-value 9.91934e-09
# Added Heathmont with p-value 1.21753e-08
# Added Ferntree Gully with p-value 6.51563e-11
# Added Gowrie with p-value 1.63293e-10
# Added Merlynston with p-value 1.75914e-08
# Added Keon Park with p-value 2.27092e-08
# Added Thomastown with p-value 1.4694e-09
# Added Werribee with p-value 5.60511e-09
# Added Ormond with p-value 2.06532e-08
# Added Bell with p-value 5.79745e-08
# Added South Morang with p-value 5.7911e-07
# Added West Footscray with p-value 1.76247e-05
# Added Heidelberg with p-value 6.39769e-06
# Added Sandown Park with p-value 5.55431e-06
# Added Jolimont with p-value 2.92777e-06
# Added Gardenvale with p-value 2.41227e-06
# Dropped Middle Brighton with p-value 0.167978
# Added Morradoo with p-value 1.79602e-05
# Added Bittern with p-value 2.61403e-06
# Added Oak Park with p-value 3.21996e-05
# Added Mernda with p-value 4.3006e-05
# Added Somerville with p-value 8.48167e-05
# Added Hawkstowe with p-value 0.000101057
# Dropped Epping with p-value 0.053305
# Added Strathmore with p-value 0.000282263
# Added Upwey with p-value 0.00028556
# Added Willison with p-value 0.000299127
# Added South Yarra with p-value 0.00082022
# Added Berwick with p-value 0.00072197
# Added Brunswick with p-value 0.00226372
# Added Canterbury with p-value 0.00639565
# Added Malvern with p-value 0.0100469
# Added Flemington Racecourse with p-value 0.0142838
# Added Hughesdale with p-value 0.0330884
# Added Epping with p-value 0.03021
# Added Albion with p-value 0.0474645

# %%
print(final_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       log_Total_Demand   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     1232.
# Date:                Sat, 25 May 2024   Prob (F-statistic):               0.00
# Time:                        23:05:53   Log-Likelihood:                -56552.
# No. Observations:               79954   AIC:                         1.135e+05
# Df Residuals:                   79749   BIC:                         1.154e+05
# Df Model:                         204
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Jacana                       0.1826      0.008     24.108      0.000       0.168       0.197
# Tooronga                     0.0278      0.008      3.485      0.000       0.012       0.044
# Officer                      0.1399      0.004     33.851      0.000       0.132       0.148
# Wattle Glen                  0.0936      0.004     23.755      0.000       0.086       0.101
# Mordialloc                   0.1965      0.006     31.509      0.000       0.184       0.209
# Aircraft                     0.0508      0.005      9.782      0.000       0.041       0.061
# Keon Park                    0.0627      0.008      8.314      0.000       0.048       0.077
# Thomastown                  -0.0398      0.007     -5.448      0.000      -0.054      -0.026
# Werribee                     0.0328      0.005      6.615      0.000       0.023       0.043
# Ormond                       0.0424      0.008      5.485      0.000       0.027       0.058
# Bell                         0.0383      0.008      4.841      0.000       0.023       0.054
# South Morang                -0.0370      0.007     -5.527      0.000      -0.050      -0.024
# West Footscray               0.0406      0.008      5.279      0.000       0.026       0.056
# Heidelberg                   0.0545      0.008      6.749      0.000       0.039       0.070
# Sandown Park                -0.0357      0.007     -5.220      0.000      -0.049      -0.022
# Jolimont                     0.0375      0.007      5.565      0.000       0.024       0.051
# Gardenvale                  -0.0371      0.007     -5.191      0.000      -0.051      -0.023
# Morradoo                     0.0086      0.002      4.257      0.000       0.005       0.013
# Bittern                     -0.0120      0.002     -5.024      0.000      -0.017      -0.007
# Oak Park                    -0.0257      0.008     -3.265      0.001      -0.041      -0.010
# Mernda                      -0.0277      0.006     -4.647      0.000      -0.039      -0.016
# Somerville                   0.0094      0.002      3.872      0.000       0.005       0.014
# Hawkstowe                   -0.0253      0.006     -4.351      0.000      -0.037      -0.014
# Strathmore                  -0.0308      0.008     -3.719      0.000      -0.047      -0.015
# Upwey                       -0.0213      0.006     -3.749      0.000      -0.032      -0.010
# Willison                     0.0171      0.005      3.567      0.000       0.008       0.027
# South Yarra                 -0.0284      0.008     -3.467      0.001      -0.044      -0.012
# Berwick                      0.0169      0.005      3.247      0.001       0.007       0.027
# Brunswick                    0.0240      0.008      2.843      0.004       0.007       0.040
# Canterbury                  -0.0186      0.007     -2.690      0.007      -0.032      -0.005
# Malvern                      0.0210      0.008      2.667      0.008       0.006       0.036
# Flemington Racecourse        0.0048      0.002      2.517      0.012       0.001       0.009
# Hughesdale                  -0.0169      0.008     -2.201      0.028      -0.032      -0.002
# Epping                      -0.0145      0.007     -2.071      0.038      -0.028      -0.001
# Albion                       0.0143      0.007      1.982      0.047       0.000       0.028
# ==============================================================================
# Omnibus:                    46591.458   Durbin-Watson:                   0.623
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           908369.057
# Skew:                          -2.425   Prob(JB):                         0.00
# Kurtosis:                      18.784   Cond. No.                         134.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pickle
with open('../output/ols_step_model_05.pkl', 'wb') as f:
    pickle.dump(final_model, f)

# %%
y_train_pred = final_model.predict(X_const[list(final_model.params.index)])
mse_ols = mean_squared_error(y, y_train_pred)
print(f"OLS Train Mean Squared Error: {mse_ols}")
# Out:
# OLS Train Mean Squared Error: 0.24092428021551174

# %%
y_pred_ols = final_model.predict(X_val_const[list(final_model.params.index)])
mse_ols = mean_squared_error(y_val, y_pred_ols)
print(f"OLS Validation Mean Squared Error: {mse_ols}")
# Out:
# OLS Validation Mean Squared Error: 0.26344487185087373

# %%
import pickle
with open('../output/ols_step_model_05.pkl', 'rb') as file:
    LR = pickle.load(file)
LR_result = pd.DataFrame([LR.params, LR.tvalues, LR.pvalues], index=['coef', 't', 'p-value']).T
LR_result.to_csv('../output/LR_estimate.csv')

# %%
test = pd.read_parquet('../data/ML_data/ML_test_data.parquet')
test.drop(['Station_Name', 'Business_Date', 'PublicHoliday', 'Date'], axis=1, inplace=True)
y_test = test['log_Total_Demand']
X_test = test.drop(['log_Total_Demand'], axis=1)
X_val_const = sm.add_constant(X_val)
X_const = sm.add_constant(X)
X_test_const = sm.add_constant(X_test)
y_pred_train = LR.predict(X_const[list(LR.params.index)])
y_pred_val = LR.predict(X_val_const[list(LR.params.index)])
y_pred_test = LR.predict(X_test_const[list(LR.params.index)])

print(f"Training Mean Squared Error: {round(mean_squared_error(y, y_pred_train),4)}, R-Squared = {round(r2_score(y, y_pred_train),4)}")
print(f"Validation Mean Squared Error: {round(mean_squared_error(y_val, y_pred_val),4)}, R-Squared = {round(r2_score(y_val, y_pred_val),4)}")
print(f"Test Mean Squared Error: {round(mean_squared_error(y_test, y_pred_test),4)}, R-Squared = {round(r2_score(y_test, y_pred_test),4)}")
# Out:
# Training Mean Squared Error: 0.2409, R-Squared = 0.7591
# Validation Mean Squared Error: 0.2634, R-Squared = 0.7359
# Test Mean Squared Error: 0.583, R-Squared = 0.3495

# %% [markdown]
# #### XGB

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
model = xgb.XGBRegressor(objective='reg:squarederror', max_depth=3, n_estimators=150)
model.fit(X, y)
joblib.dump(model, '../output/xgb_model.pkl')
y_pred_train = model.predict(X)
y_pred_val = model.predict(X_val)
y_pred_test = model.predict(X_test)


print(f"Training Mean Squared Error: {round(mean_squared_error(y, y_pred_train),4)}, R-Squared = {round(r2_score(y, y_pred_train),4)}")
print(f"Validation Mean Squared Error: {round(mean_squared_error(y_val, y_pred_val),4)}, R-Squared = {round(r2_score(y_val, y_pred_val),4)}")
print(f"Test Mean Squared Error: {round(mean_squared_error(y_test, y_pred_test),4)}, R-Squared = {round(r2_score(y_test, y_pred_test),4)}")
# Out:
# Training Mean Squared Error: 0.084, R-Squared = 0.916
# Validation Mean Squared Error: 0.1081, R-Squared = 0.8916
# Test Mean Squared Error: 0.1519, R-Squared = 0.8305

# %% [markdown]
# ### LGBM

# %%
import lightgbm as lgb

model = lgb.LGBMRegressor(objective='regression', max_depth=10, num_leaves=30, n_estimators=150, verbose=0)
model.fit(X, y)
joblib.dump(model, '../output/lgbm_model.pkl')

y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
y_pred_val = model.predict(X_val)
print(f"Training Mean Squared Error: {round(mean_squared_error(y, y_pred_train),4)}, R-Squared = {round(r2_score(y, y_pred_train),4)}")
print(f"Validation Mean Squared Error: {round(mean_squared_error(y_val, y_pred_val),4)}, R-Squared = {round(r2_score(y_val, y_pred_val),4)}")
print(f"Test Mean Squared Error: {round(mean_squared_error(y_test, y_pred_test),4)}, R-Squared = {round(r2_score(y_test, y_pred_test),4)}")
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# Training Mean Squared Error: 0.0515, R-Squared = 0.9485
# Validation Mean Squared Error: 0.0894, R-Squared = 0.9104
# Test Mean Squared Error: 0.1233, R-Squared = 0.8624
